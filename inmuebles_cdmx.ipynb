# %% [markdown]
# <a href="https://colab.research.google.com/github/Starleen1996/Biblioteca_Pandas/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # APRENDIENDO SOBRE LA BIBLIOTECA PANDAS

# %% [markdown]
# ## Importando la base de datos

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

pd.read_csv(url) # Este código lee la base de datos
# Esta tabla no nos sirve, porque los datos estan separados por ;
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
pd.read_csv(url, sep= ';') # Este código lee la base de datos posteriormente se indica que los datos estan separados por ';'
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(url, sep= ';')
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.head(5) # Muestra los primeros 5 datos de la tabla
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.tail(5) # Muestra los últimos 5 datos de la tabla
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.sample(5) # Muestra 5 datos aleatorios de la tabla
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 17210  Conjunto Comercial/Sala  Centro Histórico             0        0
# 1698        Casa de Condominio          Santa Fe             4        3
# 19902             Departamento          Coyoacán             2        0
# 15862             Departamento          Coyoacán             2        1
# 1327              Departamento          Coyoacán             1        1
#
#        Suites  Area    Valor  Condominio  Impuesto
# 17210       0   191  33950.0     21143.5    4361.0
# 1698        3   280  27300.0      5232.5       NaN
# 19902       0    80  11200.0      2205.0     420.0
# 15862       0    65  16800.0      2450.0       NaN
# 1327        1   110  31500.0     10150.0    2345.0

# %%
type(datos) # Muestra el tipo de dato de la tabla
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## EXPLORACIÓN INICIAL DE LOS DATOS

# %%
datos.sample(5)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 7027              Departamento                  Roma             3        1
# 22776  Conjunto Comercial/Sala      Centro Histórico             0        0
# 24447             Departamento  Bosques de las Lomas             3        2
# 7411              Departamento               Condesa             3        1
# 4682              Departamento              Coyoacán             3        1
#
#        Suites  Area    Valor  Condominio  Impuesto
# 7027        1   108  13300.0      3104.5     682.5
# 22776       0    35   3500.0      2082.5       NaN
# 24447       2   376  70000.0     17073.0    4840.5
# 7411        0    92  13300.0      2800.0       NaN
# 4682        1   120  22715.0      6545.0     507.5

# %%
datos.shape # Muestra la cantidad de filas y columnas de la tabla
# Out:
# (25121, 9)

# %%
datos.columns # Muestra los nombres de las columnas de la tabla
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info() # Muestra la información de la tabla
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos['Tipo'] # Muestra la columna 'Tipo' de la tabla
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[['Habitaciones','Valor']] # Muestra las dos columnas de habitaciones y Valor
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# # DEMANDA DE ML

# %% [markdown]
# ## ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos['Valor'].mean() # Aqui se pormedian todos los valores sin diversificar el tipo de propiedad
# Out:
# np.float64(36885.05048392878)

# %%
# Agrupar los datos por tipos de datos para calcular el promedio de cada propiedad
#datos.groupby('Tipo').mean()

# Este parámetro numeric_only=True (disponible desde pandas 1.5) asegura que solo se usen columnas numéricas para el promedio.

datos.groupby('Tipo')['Valor'].mean(numeric_only=True)
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
# df_tipo_precio.plot(...) Utiliza el método .plot() de pandas, que se basa en matplotlib para crear gráficos a partir de un DataFrame o Series.
#kind='barh' Especifica el tipo de gráfico: 'barh' = gráfico de barras horizontales.
# figsize=(12,8) Define el tamaño del gráfico en pulgadas: 12 de ancho × 8 de alto.
# color='green' Asigna el color verde a las barras del gráfico.

df_tipo_precio = datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind= 'barh',figsize=(12,8),color='green')
# Out:
# <Axes: ylabel='Tipo'>

# %%
datos.Tipo.unique() # Muestra los tipos de datos de la columna 'Tipo'
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salon', 'Casa Comercial',' Terreno Estandar',
                         'Cochera/Estacionamiento','Galpón/Depósio/Almacén','Tienda en Centro Comercial','Hotel','Lote/Condominio','Industria']

# %%
datos.query('@inmuebles_comerciales in Tipo')
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
datos.query('@inmuebles_comerciales not in Tipo')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df= datos.query('@inmuebles_comerciales not in Tipo')
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
df_tipo_precio = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind= 'barh',figsize=(12,8),color='green')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ## ¿Cuál es el porcentaje de cada tipo de propiedad en nuestra base de datos?"

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Tienda/Salón', 'Casa de Vecindad',
#        'Terreno Estándar', 'Loft', 'Galpón/Depósito/Almacén', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Loteo/Condominio'], dtype=object)

# %%
# Es demasiado util en el análisis de datos, permite contar los valores por tipo de inmueble
df.Tipo.value_counts()
# Out:
# Tipo
# Departamento               14764
# Tienda/Salón                1098
# Cocineta                     726
# Casa de Condominio           610
# Casa                         545
# Departamento en Hotel        455
# Galpón/Depósito/Almacén      289
# Casa de Vecindad             158
# Terreno Estándar              45
# Loft                          38
# Rancho                         8
# Estudio                        4
# Loteo/Condominio               3
# Posada/Chalé                   1
# Name: count, dtype: int64

# %%
df.Tipo.value_counts(normalize=True) # Permite mostrar el porcentaje de cada tipo de inmueble
# Out:
# Tipo
# Departamento    1.0
# Name: proportion, dtype: float64

# %%
df.query('Tipo == "Departamento"')
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df = df.query('Tipo == "Departamento"')
df.head(2)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN

# %%
porcentaje_por_tipo = df.Tipo.value_counts(normalize=True).to_frame()
porcentaje_por_tipo.plot(kind='bar',figsize=(12,8),color='green',xlabel='Tipo de inmueble',ylabel='Porcentaje')
# Out:
# <Axes: xlabel='Tipo de inmueble', ylabel='Porcentaje'>

# %%
df.shape
# Out:
# (14764, 9)

# %% [markdown]
# # HAGA LO QUE HICIMOS

# %%
# Calcular el promedio de habitaciones por departamento.
df.groupby('Tipo')[['Habitaciones']].mean().sort_values('Habitaciones')
# Out:
#               Habitaciones
# Tipo
# Departamento      2.504199

# %%
# Opción 2
df['Habitaciones'].mean()
# Out:
# np.float64(2.5041994039555675)

# %%
#Verificar cuántas colonias únicas existen en nuestra base de datos.
len(df.Colonia.unique())
# Out:
# 83

# %%
df['Colonia'].nunique()
# Out:
# 83

# %%
# Analizar qué colonias tienen el promedio de alquiler más alto.
df.groupby('Colonia')[['Valor']].mean().sort_values('Valor',ascending=False)

# Para analizar qué barrios tienen el promedio de valor de alquiler más alto, podemos:

#Agrupar nuestra base de datos por la columna "Colonia".
#Aplicar el método mean.
#Colocar el resultado en un DataFrame y ordenarlo.
#El parámetro ascending=False se utiliza en la función sort_values() para ordenar los valores en orden descendente (de mayor a menor).
# Out:
#                                   Valor
# Colonia
# Los Alpes                  54250.000000
# Bosques de Aragón          35948.718750
# Coyoacán                   33205.218609
# Roma                       32530.388539
# Lomas de Chapultepec       30232.165189
# ...                                 ...
# El Rodeo                    2275.000000
# Tláhuac                     2275.000000
# San Antonio Tecomitl        2065.000000
# Santa María Aztahuacán      1785.000000
# Potrero de San Bernardino   1190.000000
#
# [83 rows x 1 columns]

# %%
# Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.
df_colonia_precio = df.groupby('Colonia')[['Valor']].mean().sort_values('Valor',ascending=False).head()
df_colonia_precio.plot(kind='barh',figsize=(12,8),color='green')
# Out:
# <Axes: ylabel='Colonia'>

# %% [markdown]
# # TRATAMIENTO Y FILTRADO DE DATOS

# %% [markdown]
# ## Verificar Existencia de Datos Nulos

# %%
df.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
df.isnull().sum() # Devuelve cada columna con la cantidad de nulls que tiene
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %% [markdown]
# ## Tratar los datos Nulls

# %%
# Los datos nulls se tratan de diferentes maneras calculando la media, mediana según sea el caso
df.fillna(0) # Esta función llena todos lo valores nulls con ceros
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df = df.fillna(0) # Con este código realizo el cambio de nulls en el data frame
df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# ## Remover Registros Inconistentes

# %%
# Remover departamentos con valores iguales a Cero

df.query('Valor == 0 | Condominio == 0') # Muestra los valores del dtaframe que tienen valores cero en los departamentos Condominio
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
df.query('Valor == 0 | Condominio == 0').index # Se visualizan solo los indices
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
df_remover = df.query('Valor == 0 | Condominio == 0').index # Se crea un nuevo dataframe para remover los indices

# %%
df.drop(df_remover,axis=0,inplace=True) # Se remueve los indices del dataframe axis=0 son las filas, Inplace permite replicarlo en todo el dataframe

# %%
df.query('Valor == 0 | Condominio == 0').index # Se visualizan solo los indices
# Out:
# Index([], dtype='int64')

# %%
df.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
# 13  Departamento          Santa Fe             2        1       1    67
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       0.0
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5
# 13   5950.0      2061.5     514.5

# %%
df.Tipo.unique()
# Out:
# array(['Departamento'], dtype=object)

# %%
df.drop('Tipo', axis=1, inplace=True) # axis=1 se elimina la columna departamentos
df.sample(10)
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 22886               Condesa             1        0       0    40   7000.0
# 9038               Narvarte             3        1       1   112   7700.0
# 8995   Lomas de Chapultepec             1        0       1    61  16450.0
# 2665                Napoles             3        1       1   220  32200.0
# 20037               Condesa             1        0       0    51   5600.0
# 8608                   Roma             3        0       0    78   9625.0
# 1640               Santa Fe             2        1       1    95   7700.0
# 15846                  Roma             2        1       1    85  16275.0
# 9812               Santa Fe             2        1       1    78   7350.0
# 6230               Santa Fe             2        1       1   100  10500.0
#
#        Condominio  Impuesto
# 22886      2159.5       0.0
# 9038       2835.0       0.0
# 8995       2905.0     455.0
# 2665       5950.0    6475.0
# ...

# %% [markdown]
# ## Aplicar Filtros
