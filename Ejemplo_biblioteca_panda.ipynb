# %% [markdown]
# <a href="https://colab.research.google.com/github/Starleen1996/Biblioteca_Pandas/blob/main/Ejemplo_biblioteca_panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejemplo utilizando la biblioteca pandas

# %%
import pandas as pd

# %% [markdown]
# # Importa el archivo alumnos.csv y almacena su contenido en un DataFrame de Pandas.

# %%
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

pd.read_csv(url, sep=';')
# Out:
#    Nombre,Edad,Nota,Aprobado
# 0        Alberto,20,7.5,True
# 1              Ana,18,,False
# 2        Camila,27,2.5,False
# 3         David,18,5.0,False
# 4         Brian,21,10.0,True
# 5            Bruna,23,,False
# 6        Daniela,21,7.0,True
# 7        Carlos,19,6.0,False
# 8        Alicia,35,5.6,False
# 9           Victor,28,,False
# 10          Danilo,21,,False
# 11      Ignacio,24,4.5,False
# 12     Stephany,26,10.0,True
# 13        Miriam,25,9.0,True
# 14           Pablo,37,,False
# 15        Milena,29,7.0,True
# 16           Lucas,33,,False
# 17    Nadia,34,8.0,Verdadero

# %% [markdown]
# ## Mostrar el dataframe sin separación con comas ,

# %%
datos_ejemplo = pd.read_csv(url, sep=',')
datos_ejemplo
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# ## Visualiza las primeras 7 filas del DataFrame y las últimas 5.

# %%
datos_ejemplo.head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
datos_ejemplo.tail(5)
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %% [markdown]
# ## Verifica la cantidad de filas y columnas en este DataFrame.

# %%
datos_ejemplo.shape
# Out:
# (18, 4)

# %% [markdown]
# ## Explora las columnas del DataFrame y analiza los tipos de datos presentes en cada columna.

# %%
datos_ejemplo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
datos_ejemplo[['Nombre','Edad']] # Muestra las columnas Nombre y Edad del Dataframe
# Out:
#       Nombre  Edad
# 0    Alberto    20
# 1        Ana    18
# 2     Camila    27
# 3      David    18
# 4      Brian    21
# 5      Bruna    23
# 6    Daniela    21
# 7     Carlos    19
# 8     Alicia    35
# 9     Victor    28
# 10    Danilo    21
# 11   Ignacio    24
# 12  Stephany    26
# 13    Miriam    25
# 14     Pablo    37
# 15    Milena    29
# 16     Lucas    33
# 17     Nadia    34

# %%
datos_ejemplo.describe() # Muestra estadísticas descriptivas de las columnas numéricas
#
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# ## HAGA LO QUE HICIMOS
# ## TRTAMIENTO Y FILTRADO DE DATOS

# %% [markdown]
# #### Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.

# %%
datos_ejemplo.isnull().sum() # Se puede ver columnas con datos nulls
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
# Acá vamosa remplazar los datos nulls con ceros

datos_ejemplo.fillna(0, inplace=True)

datos_ejemplo.isnull().sum() # Volvemos a llamar el df para verificar los nulls
# Out:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64

# %% [markdown]
# #### Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.

# %%
# Para eliminar a los estudiantes "Alicia" y "Carlos" de nuestra base de datos, necesitamos obtener los índices de las filas donde se encuentran sus nombres y utilizar el método drop para eliminar las filas respectivas:

# Guardamos los índices de las filas a eliminar en una variable
alumnos_a_eliminar = datos_ejemplo.query('Nombre == "Alicia" | Nombre == "Carlos"').index

# Eliminamos las filas correspondientes a los estudiantes "Alicia" y "Carlos"
datos_ejemplo.drop(alumnos_a_eliminar, axis=0, inplace=True)

datos_ejemplo
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# #### Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.

# %%
# En este caso, nuestro primer paso es crear una variable en la que seleccionamos solo a los estudiantes aprobados:

seleccion = datos_ejemplo['Aprobado'] == True
seleccion
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# Name: Aprobado, dtype: bool

# %%
datos_ejemplo[seleccion]
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado]
# Index: []

# %% [markdown]
# #### Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".

# %%
#  4- Para guardar el DataFrame con solo los estudiantes aprobados, podemos comenzar guardando el DataFrame resultante del desafío 3 en una variable:
alumnos_aprobados = datos_ejemplo[seleccion]

# Luego, podemos usar el método to_csv para guardarlo en formato CSV:

alumnos_aprobados.to_csv('alumnos_aprobados.csv', index=False)

# %% [markdown]
# #### Extra: El método replace se utiliza para reemplazar un valor específico por otro. En el caso de nuestra base de datos, queremos reemplazar los valores 7.0 por 8.0. Para hacerlo, podemos usar el siguiente fragmento de código:

# %%
alumnos_aprobados.replace(7.0, 8.0)
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado]
# Index: []

# %%
# Y para guardar este cambio de forma definitiva, podemos asignarlo a nuestra variable:

alumnos_aprobados = alumnos_aprobados.replace(7.0, 8.0)

# %% [markdown]
# ## Mnipulación de Datos

# %% [markdown]
# #### Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual. Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.

# %%
datos_ejemplo = pd.read_csv(url, sep=',')

# %%
datos_ejemplo['Puntos_extras'] = datos_ejemplo['Nota'] * 0.4
datos_ejemplo
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras
# 0    Alberto    20   7.5       True           3.00
# 1        Ana    18   NaN      False            NaN
# 2     Camila    27   2.5      False           1.00
# 3      David    18   5.0      False           2.00
# 4      Brian    21  10.0       True           4.00
# 5      Bruna    23   NaN      False            NaN
# 6    Daniela    21   7.0       True           2.80
# 7     Carlos    19   6.0      False           2.40
# 8     Alicia    35   5.6      False           2.24
# 9     Victor    28   NaN      False            NaN
# 10    Danilo    21   NaN      False            NaN
# 11   Ignacio    24   4.5      False           1.80
# 12  Stephany    26  10.0       True           4.00
# 13    Miriam    25   9.0       True           3.60
# 14     Pablo    37   NaN      False            NaN
# 15    Milena    29   7.0       True           2.80
# 16     Lucas    33   NaN      False            NaN
# ...

# %% [markdown]
# #### Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras.

# %%
datos_ejemplo['Notas_Finales'] = datos_ejemplo['Nota'] + datos_ejemplo['Puntos_extras']
datos_ejemplo
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_Finales
# 0    Alberto    20   7.5       True           3.00          10.50
# 1        Ana    18   NaN      False            NaN            NaN
# 2     Camila    27   2.5      False           1.00           3.50
# 3      David    18   5.0      False           2.00           7.00
# 4      Brian    21  10.0       True           4.00          14.00
# 5      Bruna    23   NaN      False            NaN            NaN
# 6    Daniela    21   7.0       True           2.80           9.80
# 7     Carlos    19   6.0      False           2.40           8.40
# 8     Alicia    35   5.6      False           2.24           7.84
# 9     Victor    28   NaN      False            NaN            NaN
# 10    Danilo    21   NaN      False            NaN            NaN
# 11   Ignacio    24   4.5      False           1.80           6.30
# 12  Stephany    26  10.0       True           4.00          14.00
# ...

# %% [markdown]
# #### Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:
#
# True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
# False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).

# %%
datos_ejemplo['Aprobacion_Final'] = datos_ejemplo['Notas_Finales'].apply(lambda x: True if x >= 7.0 else False)
datos_ejemplo
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_Finales  \
# 0    Alberto    20   7.5       True           3.00          10.50
# 1        Ana    18   NaN      False            NaN            NaN
# 2     Camila    27   2.5      False           1.00           3.50
# 3      David    18   5.0      False           2.00           7.00
# 4      Brian    21  10.0       True           4.00          14.00
# 5      Bruna    23   NaN      False            NaN            NaN
# 6    Daniela    21   7.0       True           2.80           9.80
# 7     Carlos    19   6.0      False           2.40           8.40
# 8     Alicia    35   5.6      False           2.24           7.84
# 9     Victor    28   NaN      False            NaN            NaN
# 10    Danilo    21   NaN      False            NaN            NaN
# 11   Ignacio    24   4.5      False           1.80           6.30
# 12  Stephany    26  10.0       True           4.00          14.00
# ...

# %% [markdown]
# #### Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.

# %%
datos_ejemplo.query('Aprobado == False and Aprobacion_Final == True')
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado, Puntos_extras, Notas_Finales, Aprobación_Fianl, Aprobacion_Final]
# Index: []

# %%
# Otra Opción
seleccion = (datos_ejemplo['Aprobado'] == False) & (datos_ejemplo['Aprobacion_Final'] == True)
datos_ejemplo[seleccion]
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado, Puntos_extras, Notas_Finales, Aprobación_Fianl, Aprobacion_Final]
# Index: []
